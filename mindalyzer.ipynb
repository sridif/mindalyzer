# %%
import nltk
import csv

# %%
date_text = []
giant_string = " "

with open('tweets.csv','rU') as f:
    reader = csv.reader(f, delimiter=",")
    for row in reader:
        date_text.append('"' + row[5][:10] + '"' + "," + '"' + row[7] + '"')
        giant_string = giant_string + " " + row[7]

# %%
just_text = []
for item in all_text:
    just_text.append(item[14:-2])

# %%
date_text[:10]
# Out:
# ['"timestamp","text"',
#  '"2013-04-06","RT @umairh: Bingo. “@mjdhasan: @umairh "Creativity is the residue of time wasted." - Einstein”"',
#  '"2013-04-04","RT @BadJokeCat: You\'ve cat to be kitten me right meow."',
#  '"2013-04-04","Any SQL-guru that could help me Create temp-table with twitter users aggregated text grouped by month http://t.co/ntoRyLw8j6"',
#  '"2013-04-03","RT @hyttfors: Vanligaste orden i årsrapporter enl. DI "hållbar", "tillväxt","strategi".\nFrågan är om tillväxt är en hållbar strategi."',
#  '"2013-04-03","It hurts a programmers feelings to be seen as a function. Or a method. Or, worse, an object."',
#  '"2013-04-03","Välkommen på frukost på MINC i Malmö på tisdag kl 7:30 - tema trender i medieanalys/PR-mätning i nya medielandskapet http://t.co/7UXx6cMhtT"',
#  '"2013-04-03","Jag har nu anmält mig till #fajkhack http://t.co/Hct3de05Ey"',
#  '"2013-04-02","@EmilOberg man vill ju vara snäll. :)"',
#  '"2013-04-02","@EmilOberg insuper atmosfären :-)"']

# %%
sorted_list = sorted(date_text)

# %%
sorted_list[:10]
# Out:
# ['"2009-03-28","@Lindlund Ahhh... Livet, döden och kärleken... ;-)"',
#  '"2009-03-28","@alevin  Problem is I haven´t got the skills nor the resources to do much more development. Help wanted: http://typealyzer.com/?page_id=78"',
#  '"2009-03-28","@alevin But it would be cool to have that researched also: http://tinyurl.com/c58c27"',
#  '"2009-03-28","@alevin Cool! :-) INTP myself (but working on making that less apparent...) ;-)"',
#  '"2009-03-28","@alevin I actually thought that microblogs would have too little text in them, but a lot of people are doing it and it seems to work fine!"',
#  '"2009-03-28","@alevin Well, it isn´t intended to measure the individual, but the persona used. It´s bag of words (my subjective) and naive bayesian."',
#  '"2009-03-28","@mynewsdesk it´s not the show, it´s the social act! ;-)"',
#  '"2009-03-28","@rogerkarlsson Thanx man! Great blog post btw!"',
# ...

# %%
print(giant_string)
# Out:
#   text RT @umairh: Bingo. “@mjdhasan: @umairh "Creativity is the residue of time wasted." - Einstein” RT @BadJokeCat: You've cat to be kitten me right meow. Any SQL-guru that could help me Create temp-table with twitter users aggregated text grouped by month http://t.co/ntoRyLw8j6 RT @hyttfors: Vanligaste orden i årsrapporter enl. DI "hållbar", "tillväxt","strategi".
# ...
